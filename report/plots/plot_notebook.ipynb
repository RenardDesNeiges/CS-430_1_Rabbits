# %% [markdown]
# # Plots for report 1 of the CS-430 exercices

# %%
import csv
import sys
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
def parseCSV(address):
        """ Parses the txt file (comma-separated ==> CSV) that we use to export the plot from RePast
        """

        with open(address, newline='', encoding="utf-8-sig") as csvfile:

            reader = csv.reader(csvfile, delimiter=',', quotechar='|')

            first = True
            index = []
            tick = []
            grassTiles = []
            rabbits = []
            
            for row in reader:
                if first:
                    index = row
                    print(index)
                    first = False
                else:
                    tick.append(row[0])
                    grassTiles.append(row[1])
                    rabbits.append(row[2])
            
            return (np.array(tick),np.array(grassTiles),np.array(rabbits))

# %% [markdown]
# ## Simulation Run 1 :
# * 28 sept. 2020 à 16:01:16
# * RngSeed: 1601301675165
# * BirthTreshold: 20
# * GrassEnergy: 5.0
# * GrassGrowthRate: 50
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_1,grass_1,rabbits_1) = parseCSV('simRun_1.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
# plotting the number of grass tiles

sns.set_theme(style="darkgrid")

sns.lineplot(x=ticks_1,y=grass_1)

#plt.plot(grass_1)
#plt.plot(rabbits_1)
# Out:
# <AxesSubplot:>

# %%
length = 100
fig, ax = plt.subplots( nrows=1, ncols=1 )
ax = plt.plot(ticks_1[0:length],grass_1[0:length],color='g',linewidth=0.5,)
ax = plt.plot(ticks_1[0:length],rabbits_1[0:length],color='r',linewidth=0.5,)

fig.savefig('figure.png', dpi=500)
