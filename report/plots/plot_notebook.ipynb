# %% [markdown]
# # Plots for report 1 of the CS-430 exercices

# %%
import csv
import sys
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# File parsing routine

def parseCSV(address):
        """ Parses the txt file (comma-separated ==> CSV) that we use to export the plot from RePast
        """

        with open(address, newline='', encoding="utf-8-sig") as csvfile:

            reader = csv.reader(csvfile, delimiter=',', quotechar='|')

            first = True
            index = []
            tick = []
            grassTiles = []
            rabbits = []
            
            for row in reader:
                if first:
                    index = row
                    print(index)
                    first = False
                else:
                    tick.append(float(row[0]))
                    grassTiles.append(float(row[1]))
                    rabbits.append(float(row[2]))
            
            return (np.array(tick),np.array(grassTiles),np.array(rabbits))

# %%
# Plotting Routine

def plotPop(ticks,grass,rabbits,length,name):
    
    #defining the figure style
    plt.style.use('seaborn-whitegrid')
    
    #initialize the plot object
    fig = plt.figure()
    ax = plt.axes()
    
    #setting the axis limits
    plt.xlim(-10, ticks[length]+10)
    plt.ylim(0, max([max(grass[0:length]),max(rabbits[0:length])])+10);
    
    #plotting the grass
    x = ticks[0:length]
    y = grass[0:length]
    ax.plot(x, y,color="green", linewidth=1.0)
    
    #plotting the rabbits
    x = ticks[0:length]
    y = rabbits[0:length]
    ax.plot(x,y,color="red", linewidth=1.0)

    plt.savefig(name+".png",dpi=300)

# %%
# creating a list of dictonaries for simulation parameter and properties 

simulations = []

# %% [markdown]
# ## Simulation Run 1 (reference run) :
# * 29 sept. 2020 à 11:51:16
# * RngSeed: 1601373075162
# * BirthTreshold: 20
# * GrassEnergy: 5.0
# * GrassGrowthRate: 50
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_1,grass_1,rabbits_1) = parseCSV('simRun_1.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
# plotting the reference simulation run
plotPop(ticks_1,grass_1,rabbits_1,400,"sim1")

# %%
#basic quantifiers of the first run

start = 200
frame = 500
stop = start + frame

stable_grass_1 = grass_1[start:stop]
stable_rabbits_1 = rabbits_1[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_1)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_1)))
print("average of grass # = " + str(np.average(stable_grass_1)))
print("average of rabbits # = " + str(np.average(stable_rabbits_1)))

simParams = {
    "BirthTreshold": 20,
    "GrassEnergy": 5.0,
    "GrassGrowthRate": 50,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_1),
    "VarRabbits": np.var(stable_rabbits_1),
    "AvgGrass": np.average(stable_grass_1),
    "AvgRabbits": np.average(stable_rabbits_1)
}

simulations.append(simParams)
# Out:
# variance of grass # = 29.524556
# variance of rabbits # = 27.111084
# average of grass # = 42.038
# average of rabbits # = 234.554

# %% [markdown]
# ## Simulation Run 2 (halved birth threshold) :
# * 29 sept. 2020 à 12:03:06
# * RngSeed: 1601373784933
# * BirthTreshold: 10
# * GrassEnergy: 5.0
# * GrassGrowthRate: 50
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_2,grass_2,rabbits_2) = parseCSV('simRun_2.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
# plotting the 2nd simulation run
plotPop(ticks_2,grass_2,rabbits_2,400,"sim2")

# %%
#basic quantifiers of the 2nd run

start = 200
frame = 500
stop = start + frame

stable_grass_2 = grass_2[start:stop]
stable_rabbits_2 = rabbits_2[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_2)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_2)))
print("average of grass # = " + str(np.average(stable_grass_2)))
print("average of rabbits # = " + str(np.average(stable_rabbits_2)))

simParams = {
    "BirthTreshold": 10,
    "GrassEnergy": 5.0,
    "GrassGrowthRate": 50,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_2),
    "VarRabbits": np.var(stable_rabbits_2),
    "AvgGrass": np.average(stable_grass_2),
    "AvgRabbits": np.average(stable_rabbits_2)
}

simulations.append(simParams)
# Out:
# variance of grass # = 36.461036
# variance of rabbits # = 46.43089599999999
# average of grass # = 37.158
# average of rabbits # = 232.348

# %% [markdown]
# ## Simulation Run 3 (quartered birth threshold) :
# * 29 sept. 2020 à 12:13:09
# * RngSeed: 1601374387634
# * BirthTreshold: 5
# * GrassEnergy: 5.0
# * GrassGrowthRate: 50
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_3,grass_3,rabbits_3) = parseCSV('simRun_3.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
# plotting the 3rd simulation run
plotPop(ticks_3,grass_3,rabbits_3,400,"sim3")

# %%
#basic quantifiers of the 3rd run

start = 200
frame = 500
stop = start + frame

stable_grass_3 = grass_3[start:stop]
stable_rabbits_3 = rabbits_3[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_3)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_3)))
print("average of grass # = " + str(np.average(stable_grass_3)))
print("average of rabbits # = " + str(np.average(stable_rabbits_3)))

simParams = {
    "BirthTreshold": 5,
    "GrassEnergy": 5.0,
    "GrassGrowthRate": 50,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_3),
    "VarRabbits": np.var(stable_rabbits_3),
    "AvgGrass": np.average(stable_grass_3),
    "AvgRabbits": np.average(stable_rabbits_3)
}

simulations.append(simParams)
# Out:
# variance of grass # = 33.090444000000005
# variance of rabbits # = 82.1811
# average of grass # = 32.166
# average of rabbits # = 215.73

# %% [markdown]
# ## Simulation Run 4 (doubled grass growth rate) :
# * 29 sept. 2020 à 12:55:48
# * RngSeed: 1601376946974
# * BirthTreshold: 20
# * GrassEnergy: 5.0
# * GrassGrowthRate: 100
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_4,grass_4,rabbits_4) = parseCSV('simRun_4.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
# plotting the 3rd simulation run
plotPop(ticks_4,grass_4,rabbits_4,400,"sim4")

# %%
#basic quantifiers of the 4th run

start = 200
frame = 500
stop = start + frame

stable_grass_4 = grass_4[start:stop]
stable_rabbits_4 = rabbits_4[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_4)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_4)))
print("average of grass # = " + str(np.average(stable_grass_4)))
print("average of rabbits # = " + str(np.average(stable_rabbits_4)))

simParams = {
    "BirthTreshold": 20,
    "GrassEnergy": 5.0,
    "GrassGrowthRate": 100,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_4),
    "VarRabbits": np.var(stable_rabbits_4),
    "AvgGrass": np.average(stable_grass_4),
    "AvgRabbits": np.average(stable_rabbits_4)
}

simulations.append(simParams)
# Out:
# variance of grass # = 8.582956
# variance of rabbits # = 22.916784
# average of grass # = 9.362
# average of rabbits # = 366.404

# %% [markdown]
# ## Simulation Run 5 (quadrupled grass growth rate) :
# * 29 sept. 2020 à 12:59:30
# * RngSeed: 1601377168482
# * BirthTreshold: 20
# * GrassEnergy: 5.0
# * GrassGrowthRate: 200
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_5,grass_5,rabbits_5) = parseCSV('simRun_5.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
# plotting the 3rd simulation run
plotPop(ticks_5,grass_5,rabbits_5,400,"sim5")

# %%
#basic quantifiers of the 5th run

start = 200
frame = 500
stop = start + frame

stable_grass_5 = grass_5[start:stop]
stable_rabbits_5 = rabbits_5[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_5)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_5)))
print("average of grass # = " + str(np.average(stable_grass_5)))
print("average of rabbits # = " + str(np.average(stable_rabbits_5)))

simParams = {
    "BirthTreshold": 20,
    "GrassEnergy": 5.0,
    "GrassGrowthRate": 200,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_5),
    "VarRabbits": np.var(stable_rabbits_5),
    "AvgGrass": np.average(stable_grass_5),
    "AvgRabbits": np.average(stable_rabbits_5)
}

simulations.append(simParams)
# Out:
# variance of grass # = 1.880204
# variance of rabbits # = 5.528556
# average of grass # = 1.714
# average of rabbits # = 394.038

# %% [markdown]
# ## Simulation Run 6 (tripled grass growth rate) :
# * 29 sept. 2020 à 13:04:46
# * RngSeed: 1601377484664
# * BirthTreshold: 20
# * GrassEnergy: 5.0
# * GrassGrowthRate: 150
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_6,grass_6,rabbits_6) = parseCSV('simRun_6.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
plotPop(ticks_6,grass_6,rabbits_6,400,"sim6")

# %%
#basic quantifiers of the 6th run

start = 200
frame = 500
stop = start + frame

stable_grass_6 = grass_6[start:stop]
stable_rabbits_6 = rabbits_6[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_6)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_6)))
print("average of grass # = " + str(np.average(stable_grass_6)))
print("average of rabbits # = " + str(np.average(stable_rabbits_6)))

simParams = {
    "BirthTreshold": 20,
    "GrassEnergy": 5.0,
    "GrassGrowthRate": 150,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_6),
    "VarRabbits": np.var(stable_rabbits_6),
    "AvgGrass": np.average(stable_grass_6),
    "AvgRabbits": np.average(stable_rabbits_6)
}

simulations.append(simParams)
# Out:
# variance of grass # = 2.954956
# variance of rabbits # = 9.221904
# average of grass # = 3.138
# average of rabbits # = 388.564

# %% [markdown]
# ## Simulation run 7 (grass energy doubled) :
# * 29 sept. 2020 à 13:09:08
# * RngSeed: 1601377747010
# * BirthTreshold: 20
# * GrassEnergy: 10.0
# * GrassGrowthRate: 50
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_7,grass_7,rabbits_7) = parseCSV('simRun_7.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
plotPop(ticks_7,grass_7,rabbits_7,400,"sim7")

# %%
#basic quantifiers of the 7th run

start = 200
frame = 500
stop = start + frame

stable_grass_7 = grass_7[start:stop]
stable_rabbits_7 = rabbits_7[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_7)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_7)))
print("average of grass # = " + str(np.average(stable_grass_7)))
print("average of rabbits # = " + str(np.average(stable_rabbits_7)))

simParams = {
    "BirthTreshold": 20,
    "GrassEnergy": 10.0,
    "GrassGrowthRate": 50,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_7),
    "VarRabbits": np.var(stable_rabbits_7),
    "AvgGrass": np.average(stable_grass_7),
    "AvgRabbits": np.average(stable_rabbits_7)
}

simulations.append(simParams)
# Out:
# variance of grass # = 8.808304
# variance of rabbits # = 42.954156000000005
# average of grass # = 10.236
# average of rabbits # = 332.562

# %% [markdown]
# ## Simulation Run 8 (tripled grassEnergy) :
# * 29 sept. 2020 à 13:16:25
# * RngSeed: 1601378183423
# * BirthTreshold: 20
# * GrassEnergy: 15.0
# * GrassGrowthRate: 50
# * GridSize: 20
# * NumInitGrass: 100
# * NumInitRabbits: 30

# %%
(ticks_8,grass_8,rabbits_8) = parseCSV('simRun_8.txt')
# Out:
# ['"tick"', ' "Number of grass tile"', ' "Number of rabbits"']

# %%
plotPop(ticks_8,grass_8,rabbits_8,400,"sim8")

# %%
#basic quantifiers of the 8th run

start = 200
frame = 500
stop = start + frame

stable_grass_8 = grass_8[start:stop]
stable_rabbits_8 = rabbits_8[start:stop]

print("variance of grass # = " + str(np.var(stable_grass_8)))
print("variance of rabbits # = " + str(np.var(stable_rabbits_8)))
print("average of grass # = " + str(np.average(stable_grass_8)))
print("average of rabbits # = " + str(np.average(stable_rabbits_8)))

simParams = {
    "BirthTreshold": 20,
    "GrassEnergy": 15.0,
    "GrassGrowthRate": 50,
    "GridSize": 20,
    "NumInitGrass": 100,
    "NumInitRabbits": 30,
    "VarGrass": np.var(stable_grass_8),
    "VarRabbits": np.var(stable_rabbits_8),
    "AvgGrass": np.average(stable_grass_8),
    "AvgRabbits": np.average(stable_rabbits_8)
}

simulations.append(simParams)
# Out:
# variance of grass # = 6.248844000000001
# variance of rabbits # = 36.831663999999996
# average of grass # = 6.466
# average of rabbits # = 346.156

# %% [markdown]
# # Plotting the reaction to variation of different parameters

# %%
print(simulations)
# Out:
# [{'BirthTreshold': 20, 'GrassEnergy': 5.0, 'GrassGrowthRate': 50, 'GridSize': 20, 'NumInitGrass': 100, 'NumInitRabbits': 30, 'VarGrass': 29.524556, 'VarRabbits': 27.111084, 'AvgGrass': 42.038, 'AvgRabbits': 234.554}, {'BirthTreshold': 10, 'GrassEnergy': 5.0, 'GrassGrowthRate': 50, 'GridSize': 20, 'NumInitGrass': 100, 'NumInitRabbits': 30, 'VarGrass': 36.461036, 'VarRabbits': 46.43089599999999, 'AvgGrass': 37.158, 'AvgRabbits': 232.348}, {'BirthTreshold': 5, 'GrassEnergy': 5.0, 'GrassGrowthRate': 50, 'GridSize': 20, 'NumInitGrass': 100, 'NumInitRabbits': 30, 'VarGrass': 33.090444000000005, 'VarRabbits': 82.1811, 'AvgGrass': 32.166, 'AvgRabbits': 215.73}, {'BirthTreshold': 20, 'GrassEnergy': 5.0, 'GrassGrowthRate': 100, 'GridSize': 20, 'NumInitGrass': 100, 'NumInitRabbits': 30, 'VarGrass': 8.582956, 'VarRabbits': 22.916784, 'AvgGrass': 9.362, 'AvgRabbits': 366.404}, {'BirthTreshold': 20, 'GrassEnergy': 5.0, 'GrassGrowthRate': 200, 'GridSize': 20, 'NumInitGrass': 100, 'NumInitRabbits': 
# ...

# %% [markdown]
# ## Plotting the reaction to birthTreshold

# %%
plt.style.use('seaborn-whitegrid')

#initialize the plot object
fig = plt.figure()
ax = plt.axes()

x = list((sim['BirthTreshold'] for sim in simulations))

mk = 'o'
sz = 5

#plotting
y = list((sim['VarGrass'] for sim in simulations))
ax.plot(x, y,color="green", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['VarRabbits'] for sim in simulations))
ax.plot(x, y,color="red", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['AvgGrass'] for sim in simulations))
ax.plot(x, y,color="blue", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['AvgRabbits'] for sim in simulations))
ax.plot(x, y,color="orange", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

# %% [markdown]
# ## Plotting the reaction to GrassGrowthRate

# %%
plt.style.use('seaborn-whitegrid')

#initialize the plot object
fig = plt.figure()
ax = plt.axes()

x = list((sim['GrassGrowthRate'] for sim in simulations))

mk = 'o'
sz = 5

#plotting
y = list((sim['VarGrass'] for sim in simulations))
ax.plot(x, y,color="green", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['VarRabbits'] for sim in simulations))
ax.plot(x, y,color="red", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['AvgGrass'] for sim in simulations))
ax.plot(x, y,color="blue", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['AvgRabbits'] for sim in simulations))
ax.plot(x, y,color="orange", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

# %% [markdown]
# ## Plotting the reaction to GrassEnergy

# %%
plt.style.use('seaborn-whitegrid')

#initialize the plot object
fig = plt.figure()
ax = plt.axes()

x = list((sim['GrassEnergy'] for sim in simulations))

mk = 'o'
sz = 5

#plotting
y = list((sim['VarGrass'] for sim in simulations))
ax.plot(x, y,color="green", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['VarRabbits'] for sim in simulations))
ax.plot(x, y,color="red", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['AvgGrass'] for sim in simulations))
ax.plot(x, y,color="blue", linewidth=0,marker=mk,markersize=sz,fillstyle='none')

y = list((sim['AvgRabbits'] for sim in simulations))
ax.plot(x, y,color="orange", linewidth=0,marker=mk,markersize=sz,fillstyle='none')
